# %% [markdown]
# # Eigenfaces 🎭
# ## By Rohan Naphade and Nir Pechuk
# Follow along to see how we can use PCA to perform unconstrained facial recognition!

# %% [markdown]
# ## Step 1: Load data

# %% [markdown]
# ## Step 2: Mean-center data

# %% [markdown]
# Let's print some faces before/after mean-centering!

# %% [markdown]
# ## Step 3: Perform a PCA to find Top-K Variance Dimensions

# %% [markdown]
# What do our newly-found "eigenfaces" look like?

# %% [markdown]
# ## Step 4: Project Training Data Onto K-Dim Subspace

# %% [markdown]
# What have we lost? Let's try to reconstruct a face and compare! The original projection is called the *Forward Projection* and this process is *Backwards Projection*.

# %% [markdown]
# ## Step 5: Center and Project New Example Onto Subspace

# %% [markdown]
# ## Step 6: Find Closest Training Example Within Subspace & Classify!
